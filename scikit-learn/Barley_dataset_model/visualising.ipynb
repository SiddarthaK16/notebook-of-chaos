# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("Training_Set.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beginning_Stocks         41 non-null     float64
#  1   Production               41 non-null     float64
#  2   Imports                  41 non-null     float64
#  3   Total_Supply             41 non-null     float64
#  4   Food_Alcohol_Industrial  41 non-null     float64
#  5   Seed_Use                 41 non-null     float64
#  6   Feed_Residual            41 non-null     float64
#  7   Total_Domestic_Use       41 non-null     float64
#  8   Exports                  41 non-null     float64
#  9   Total_Use                41 non-null     float64
#  10  Ending_Stocks            41 non-null     float64
#  11  Year                     41 non-null     int64
# dtypes: float64(11), int64(1)
# memory usage: 4.0 KB

# %%
df_features= df.drop("Ending_Stocks" , axis=1)
df_labels=df["Ending_Stocks"].copy()

# %%
df_features.corr()
# Out:
#                          Beginning_Stocks  Production   Imports  Total_Supply  \
# Beginning_Stocks                 1.000000    0.649398 -0.324588      0.832788
# Production                       0.649398    1.000000 -0.186471      0.957212
# Imports                         -0.324588   -0.186471  1.000000     -0.175844
# Total_Supply                     0.832788    0.957212 -0.175844      1.000000
# Food_Alcohol_Industrial          0.249604    0.139314  0.199568      0.215712
# Seed_Use                         0.677809    0.899404 -0.317616      0.885082
# Feed_Residual                    0.695877    0.955305 -0.033578      0.956740
# Total_Domestic_Use               0.708729    0.954942 -0.032871      0.961623
# Exports                          0.688979    0.702263 -0.055785      0.770809
# Total_Use                        0.748654    0.943414 -0.041609      0.968402
# Year                            -0.583199   -0.801429  0.296732     -0.779270
#
#                          Food_Alcohol_Industrial  Seed_Use  Feed_Residual  \
# Beginning_Stocks                        0.249604  0.677809       0.695877
# Production                              0.139314  0.899404       0.955305
# Imports                                 0.199568 -0.317616      -0.033578
# Total_Supply                            0.215712  0.885082       0.956740
# Food_Alcohol_Industrial                 1.000000 -0.028115       0.148507
# Seed_Use                               -0.028115  1.000000       0.894611
# Feed_Residual                           0.148507  0.894611       1.000000
# Total_Domestic_Use                      0.217661  0.890216       0.997262
# Exports                                 0.270595  0.660968       0.689371
# Total_Use                               0.246970  0.881291       0.972505
# Year                                    0.095977 -0.910596      -0.807362
#
#                          Total_Domestic_Use   Exports  Total_Use      Year
# Beginning_Stocks                   0.708729  0.688979   0.748654 -0.583199
# Production                         0.954942  0.702263   0.943414 -0.801429
# Imports                           -0.032871 -0.055785  -0.041609  0.296732
# Total_Supply                       0.961623  0.770809   0.968402 -0.779270
# Food_Alcohol_Industrial            0.217661  0.270595   0.246970  0.095977
# Seed_Use                           0.890216  0.660968   0.881291 -0.910596
# Feed_Residual                      0.997262  0.689371   0.972505 -0.807362
# Total_Domestic_Use                 1.000000  0.703396   0.978681 -0.798182
# Exports                            0.703396  1.000000   0.834389 -0.607960
# Total_Use                          0.978681  0.834389   1.000000 -0.794608
# Year                              -0.798182 -0.607960  -0.794608  1.000000

# %%
pd.plotting.scatter_matrix(df_features , alpha=0.3 , figsize=(12,8) , grid=True)
# Out:
# array([[<Axes: xlabel='Beginning_Stocks', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Production', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Imports', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Total_Supply', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Seed_Use', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Exports', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Total_Use', ylabel='Beginning_Stocks'>,
#         <Axes: xlabel='Year', ylabel='Beginning_Stocks'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Production'>,
#         <Axes: xlabel='Production', ylabel='Production'>,
#         <Axes: xlabel='Imports', ylabel='Production'>,
#         <Axes: xlabel='Total_Supply', ylabel='Production'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Production'>,
#         <Axes: xlabel='Seed_Use', ylabel='Production'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Production'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Production'>,
#         <Axes: xlabel='Exports', ylabel='Production'>,
#         <Axes: xlabel='Total_Use', ylabel='Production'>,
#         <Axes: xlabel='Year', ylabel='Production'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Imports'>,
#         <Axes: xlabel='Production', ylabel='Imports'>,
#         <Axes: xlabel='Imports', ylabel='Imports'>,
#         <Axes: xlabel='Total_Supply', ylabel='Imports'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Imports'>,
#         <Axes: xlabel='Seed_Use', ylabel='Imports'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Imports'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Imports'>,
#         <Axes: xlabel='Exports', ylabel='Imports'>,
#         <Axes: xlabel='Total_Use', ylabel='Imports'>,
#         <Axes: xlabel='Year', ylabel='Imports'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Total_Supply'>,
#         <Axes: xlabel='Production', ylabel='Total_Supply'>,
#         <Axes: xlabel='Imports', ylabel='Total_Supply'>,
#         <Axes: xlabel='Total_Supply', ylabel='Total_Supply'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Total_Supply'>,
#         <Axes: xlabel='Seed_Use', ylabel='Total_Supply'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Total_Supply'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Total_Supply'>,
#         <Axes: xlabel='Exports', ylabel='Total_Supply'>,
#         <Axes: xlabel='Total_Use', ylabel='Total_Supply'>,
#         <Axes: xlabel='Year', ylabel='Total_Supply'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Production', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Imports', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Total_Supply', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Seed_Use', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Exports', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Total_Use', ylabel='Food_Alcohol_Industrial'>,
#         <Axes: xlabel='Year', ylabel='Food_Alcohol_Industrial'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Seed_Use'>,
#         <Axes: xlabel='Production', ylabel='Seed_Use'>,
#         <Axes: xlabel='Imports', ylabel='Seed_Use'>,
#         <Axes: xlabel='Total_Supply', ylabel='Seed_Use'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Seed_Use'>,
#         <Axes: xlabel='Seed_Use', ylabel='Seed_Use'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Seed_Use'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Seed_Use'>,
#         <Axes: xlabel='Exports', ylabel='Seed_Use'>,
#         <Axes: xlabel='Total_Use', ylabel='Seed_Use'>,
#         <Axes: xlabel='Year', ylabel='Seed_Use'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Production', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Imports', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Total_Supply', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Seed_Use', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Exports', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Total_Use', ylabel='Feed_Residual'>,
#         <Axes: xlabel='Year', ylabel='Feed_Residual'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Production', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Imports', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Total_Supply', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Seed_Use', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Exports', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Total_Use', ylabel='Total_Domestic_Use'>,
#         <Axes: xlabel='Year', ylabel='Total_Domestic_Use'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Exports'>,
#         <Axes: xlabel='Production', ylabel='Exports'>,
#         <Axes: xlabel='Imports', ylabel='Exports'>,
#         <Axes: xlabel='Total_Supply', ylabel='Exports'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Exports'>,
#         <Axes: xlabel='Seed_Use', ylabel='Exports'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Exports'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Exports'>,
#         <Axes: xlabel='Exports', ylabel='Exports'>,
#         <Axes: xlabel='Total_Use', ylabel='Exports'>,
#         <Axes: xlabel='Year', ylabel='Exports'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Total_Use'>,
#         <Axes: xlabel='Production', ylabel='Total_Use'>,
#         <Axes: xlabel='Imports', ylabel='Total_Use'>,
#         <Axes: xlabel='Total_Supply', ylabel='Total_Use'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Total_Use'>,
#         <Axes: xlabel='Seed_Use', ylabel='Total_Use'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Total_Use'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Total_Use'>,
#         <Axes: xlabel='Exports', ylabel='Total_Use'>,
#         <Axes: xlabel='Total_Use', ylabel='Total_Use'>,
#         <Axes: xlabel='Year', ylabel='Total_Use'>],
#        [<Axes: xlabel='Beginning_Stocks', ylabel='Year'>,
#         <Axes: xlabel='Production', ylabel='Year'>,
#         <Axes: xlabel='Imports', ylabel='Year'>,
#         <Axes: xlabel='Total_Supply', ylabel='Year'>,
#         <Axes: xlabel='Food_Alcohol_Industrial', ylabel='Year'>,
#         <Axes: xlabel='Seed_Use', ylabel='Year'>,
#         <Axes: xlabel='Feed_Residual', ylabel='Year'>,
#         <Axes: xlabel='Total_Domestic_Use', ylabel='Year'>,
#         <Axes: xlabel='Exports', ylabel='Year'>,
#         <Axes: xlabel='Total_Use', ylabel='Year'>,
#         <Axes: xlabel='Year', ylabel='Year'>]], dtype=object)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df_features)

# %%
X=pd.DataFrame(
    X ,
    columns = df_features.columns,
    index=df_features.index
)

# %%
X.head()
# Out:
#    Beginning_Stocks  Production   Imports  Total_Supply  \
# 0         -0.731895    0.237613 -0.450068     -0.157977
# 1         -0.200363    0.268642 -0.718061      0.051386
# 2         -0.228900    0.629985 -0.863403      0.286465
# 3          0.453105    0.847668 -0.845277      0.713706
# 4          1.256915    0.270207 -0.814866      0.620501
#
#    Food_Alcohol_Industrial  Seed_Use  Feed_Residual  Total_Domestic_Use  \
# 0                -3.229978  0.878151       0.371496            0.137088
# 1                -2.331710  1.390661       0.218602            0.094075
# 2                -2.093107  1.103655       0.254641            0.131193
# 3                 0.012207  0.447643       0.710825            0.691063
# 4                 0.601696  0.509144       0.556044            0.596778
#
#     Exports  Total_Use      Year
# 0 -0.771641  -0.116664 -1.690309
# 1  0.496108   0.216300 -1.605793
# 2  0.215577   0.164022 -1.521278
# 3 -0.715843   0.329030 -1.436762
# 4  0.134748   0.501697 -1.352247
