# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set_style(style="darkgrid")
sns.scatterplot(x="total_bill" , y="tip" , hue="sex" , data=tips)
plt.xlabel("Total bill")
plt.ylabel("Tip")
plt.title("TOTAL BILL vs TIP LEFT")
plt.grid(True)
plt.legend()

# %%
sns.set_style(style="darkgrid")
sns.barplot(x="size" , y="tip" , hue="sex" , data=tips , ci=None)
plt.xlabel("Number of people in a table")
plt.ylabel("Tip")
plt.title("Number of people vs Tip left")
plt.grid(True)
plt.legend()
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\3286349449.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="size" , y="tip" , hue="sex" , data=tips , ci=None)

# %%
tips[tips['size'] == 5].groupby('sex')['tip'].describe()
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\1235817238.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips[tips['size'] == 5].groupby('sex')['tip'].describe()
#         count  mean  std   min   25%   50%   75%   max
# sex
# Male      4.0  3.75  1.5  2.00  2.75  4.00  5.00  5.00
# Female    1.0  5.14  NaN  5.14  5.14  5.14  5.14  5.14

# %%
sns.set_style("whitegrid")
sns.barplot(
    x="day", y="tip", hue="sex", data=tips,
    palette="rocket", edgecolor="black", alpha=0.9, ci=None
)
plt.title("Day vs Tip Left 💰")
plt.xlabel("Day of the Week")
plt.ylabel("Average Tip ($)")
plt.legend(title="Sex")
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\3154718615.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\Siddartha\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Siddartha\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_style("whitegrid")
sns.barplot(
    x="smoker", y="tip", hue="sex", data=tips,
    palette="rocket", edgecolor="black", alpha=0.9, ci=None
)
plt.title("Does smoking affects tipping 💰")
plt.xlabel("Type")
plt.ylabel("Average Tip ($)")
plt.legend(title="Sex")
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\1538278008.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\Siddartha\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Arial.
#   func(*args, **kwargs)
# C:\Users\Siddartha\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_style("darkgrid")
sns.barplot(
    x="time", y="tip", hue="sex", data=tips,
    palette="magma", edgecolor="black", alpha=0.9, ci=None
)
plt.title("Which time implies more tip")
plt.xlabel("Type of  mean")
plt.ylabel("Average Tip ($)")
plt.legend(title="Sex")
plt.tight_layout()
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\2393401587.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
sns.set_style("darkgrid")
sns.barplot(
    x="smoker", y="total_bill", hue="sex", data=tips,
    palette="magma", edgecolor="black", alpha=0.9, ci=None
)
plt.title("Do smokers eat more?")
plt.xlabel("Smoker or not")
plt.ylabel("Average Bill")
plt.legend(title="Sex")
plt.tight_layout()
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\449109116.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
sns.set_style("darkgrid")

order = ["Thur", "Fri", "Sat", "Sun"]
sns.barplot(
    x="day", y="size", hue="smoker", data=tips,
    order=order, palette="flare", edgecolor="black", alpha=0.9, ci=None
)                                            

plt.title("When does smokers meetup happen?")
plt.xlabel("Day")
plt.ylabel("Number of people")
plt.legend(title="Smoker or not")
plt.tight_layout()
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_10744\1956623412.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
