# %%
import pandas as pd

# %%
df=pd.read_csv("movies.csv")
df
# Out:
#                  Actor               Film  Year      Genre  \
# 0       Shah Rukh Khan              Jawan  2023     Action
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 2           Aamir Khan             Dangal  2016  Biography
# 3        Ranbir Kapoor             Animal  2023      Drama
# 4        Ranveer Singh          Padmaavat  2018      Drama
# 5   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 6         Rajkumar Rao              Stree  2018     Horror
# 7       Hrithik Roshan                War  2019     Action
# 8         Akshay Kumar                2.O  2018     Sci-Fi
# 9        Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 10        Varun Dhawan            Dilwale  2015    Romance
# 11       Vicky Kaushal             Chaava  2025    Period
# 12      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
#
#     BoxOffice in INR CRORE  IMDb
# 0                     1160   7.8
# 1                      923   8.0
# 2                     2024   8.4
# 3                      915   8.2
# 4                      585   7.1
# 5                      456   8.2
# 6                      180   7.6
# 7                      471   6.9
# 8                      745   6.0
# 9                      397   7.2
# 10                     375   6.2
# 11                     706   7.8
# 12                     619   7.5

# %%
df.sort_values("Year", ascending=False)  # For desceding order
# Out:
#                  Actor               Film  Year      Genre  \
# 11       Vicky Kaushal             Chaava  2025    Period
# 9        Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 12      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 3        Ranbir Kapoor             Animal  2023      Drama
# 0       Shah Rukh Khan              Jawan  2023     Action
# 7       Hrithik Roshan                War  2019     Action
# 8         Akshay Kumar                2.O  2018     Sci-Fi
# 4        Ranveer Singh          Padmaavat  2018      Drama
# 6         Rajkumar Rao              Stree  2018     Horror
# 5   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 2           Aamir Khan             Dangal  2016  Biography
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 10        Varun Dhawan            Dilwale  2015    Romance
#
#     BoxOffice in INR CRORE  IMDb
# 11                     706   7.8
# 9                      397   7.2
# 12                     619   7.5
# 3                      915   8.2
# 0                     1160   7.8
# 7                      471   6.9
# 8                      745   6.0
# 4                      585   7.1
# 6                      180   7.6
# 5                      456   8.2
# 2                     2024   8.4
# 1                      923   8.0
# 10                     375   6.2

# %%
df.sort_values("BoxOffice in INR CRORE",ascending=False)
# Out:
#                  Actor               Film  Year      Genre  \
# 2           Aamir Khan             Dangal  2016  Biography
# 0       Shah Rukh Khan              Jawan  2023     Action
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 3        Ranbir Kapoor             Animal  2023      Drama
# 8         Akshay Kumar                2.O  2018     Sci-Fi
# 11       Vicky Kaushal             Chaava  2025    Period
# 12      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 4        Ranveer Singh          Padmaavat  2018      Drama
# 7       Hrithik Roshan                War  2019     Action
# 5   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 9        Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 10        Varun Dhawan            Dilwale  2015    Romance
# 6         Rajkumar Rao              Stree  2018     Horror
#
#     BoxOffice in INR CRORE  IMDb
# 2                     2024   8.4
# 0                     1160   7.8
# 1                      923   8.0
# 3                      915   8.2
# 8                      745   6.0
# 11                     706   7.8
# 12                     619   7.5
# 4                      585   7.1
# 7                      471   6.9
# 5                      456   8.2
# 9                      397   7.2
# 10                     375   6.2
# 6                      180   7.6

# %%
df2=df.sort_values(["Year", "BoxOffice in INR CRORE"]).copy() # If year is tied , then it will watch boxoffice one to sort

# %%
df2
# Out:
#                  Actor               Film  Year      Genre  \
# 10        Varun Dhawan            Dilwale  2015    Romance
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 2           Aamir Khan             Dangal  2016  Biography
# 6         Rajkumar Rao              Stree  2018     Horror
# 5   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 4        Ranveer Singh          Padmaavat  2018      Drama
# 8         Akshay Kumar                2.O  2018     Sci-Fi
# 7       Hrithik Roshan                War  2019     Action
# 3        Ranbir Kapoor             Animal  2023      Drama
# 0       Shah Rukh Khan              Jawan  2023     Action
# 9        Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 12      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 11       Vicky Kaushal             Chaava  2025    Period
#
#     BoxOffice in INR CRORE  IMDb
# 10                     375   6.2
# 1                      923   8.0
# 2                     2024   8.4
# 6                      180   7.6
# 5                      456   8.2
# 4                      585   7.1
# 8                      745   6.0
# 7                      471   6.9
# 3                      915   8.2
# 0                     1160   7.8
# 9                      397   7.2
# 12                     619   7.5
# 11                     706   7.8

# %%
df2.reset_index(drop=True,inplace=True)  #Use drop=true if u do not want old index in seperate column and inplace if you want to change df2

# %%
df2
# Out:
#                  Actor               Film  Year      Genre  \
# 0         Varun Dhawan            Dilwale  2015    Romance
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 2           Aamir Khan             Dangal  2016  Biography
# 3         Rajkumar Rao              Stree  2018     Horror
# 4   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 5        Ranveer Singh          Padmaavat  2018      Drama
# 6         Akshay Kumar                2.O  2018     Sci-Fi
# 7       Hrithik Roshan                War  2019     Action
# 8        Ranbir Kapoor             Animal  2023      Drama
# 9       Shah Rukh Khan              Jawan  2023     Action
# 10       Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 11      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 12       Vicky Kaushal             Chaava  2025    Period
#
#     BoxOffice in INR CRORE  IMDb
# 0                      375   6.2
# 1                      923   8.0
# 2                     2024   8.4
# 3                      180   7.6
# 4                      456   8.2
# 5                      585   7.1
# 6                      745   6.0
# 7                      471   6.9
# 8                      915   8.2
# 9                     1160   7.8
# 10                     397   7.2
# 11                     619   7.5
# 12                     706   7.8

# %% [markdown]
# ### The df.sort_index() function is used to sort the DataFrame based on its index values. If the index is not in a sequential order (e.g., you have dropped rows or performed other operations that change the index), you can use sort_index() to restore it to a sorted order.

# %%
df2["Rank"]=df2["IMDb"].rank(ascending=False)

# %%
df2
# Out:
#                  Actor               Film  Year      Genre  \
# 0         Varun Dhawan            Dilwale  2015    Romance
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 2           Aamir Khan             Dangal  2016  Biography
# 3         Rajkumar Rao              Stree  2018     Horror
# 4   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 5        Ranveer Singh          Padmaavat  2018      Drama
# 6         Akshay Kumar                2.O  2018     Sci-Fi
# 7       Hrithik Roshan                War  2019     Action
# 8        Ranbir Kapoor             Animal  2023      Drama
# 9       Shah Rukh Khan              Jawan  2023     Action
# 10       Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 11      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 12       Vicky Kaushal             Chaava  2025    Period
#
#     BoxOffice in INR CRORE  IMDb  Rank
# 0                      375   6.2  12.0
# 1                      923   8.0   4.0
# 2                     2024   8.4   1.0
# 3                      180   7.6   7.0
# 4                      456   8.2   2.5
# 5                      585   7.1  10.0
# 6                      745   6.0  13.0
# 7                      471   6.9  11.0
# 8                      915   8.2   2.5
# 9                     1160   7.8   5.5
# 10                     397   7.2   9.0
# 11                     619   7.5   8.0
# 12                     706   7.8   5.5

# %% [markdown]
# ### The .rank() function in pandas is used to assign ranks to numeric values in a column, like scores or points. By default, it gives the average rank to tied values, which can result in decimal numbers. For example, if two people share the top score, they both get a rank of 1.5. You can customize the ranking behavior using the method parameter. One useful option is method='dense', which assigns the same rank to ties but doesn’t leave gaps in the ranking sequence. This is helpful when you want a clean, consecutive ranking system without skips.

# %%
df2["Rank"]=df2["IMDb"].rank(ascending=False,method='dense').astype(int)

# %%
df2
# Out:
#                  Actor               Film  Year      Genre  \
# 0         Varun Dhawan            Dilwale  2015    Romance
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 2           Aamir Khan             Dangal  2016  Biography
# 3         Rajkumar Rao              Stree  2018     Horror
# 4   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 5        Ranveer Singh          Padmaavat  2018      Drama
# 6         Akshay Kumar                2.O  2018     Sci-Fi
# 7       Hrithik Roshan                War  2019     Action
# 8        Ranbir Kapoor             Animal  2023      Drama
# 9       Shah Rukh Khan              Jawan  2023     Action
# 10       Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 11      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 12       Vicky Kaushal             Chaava  2025    Period
#
#     BoxOffice in INR CRORE  IMDb  Rank
# 0                      375   6.2    10
# 1                      923   8.0     3
# 2                     2024   8.4     1
# 3                      180   7.6     5
# 4                      456   8.2     2
# 5                      585   7.1     8
# 6                      745   6.0    11
# 7                      471   6.9     9
# 8                      915   8.2     2
# 9                     1160   7.8     4
# 10                     397   7.2     7
# 11                     619   7.5     6
# 12                     706   7.8     4

# %%
df2.sort_values("Rank")
# Out:
#                  Actor               Film  Year      Genre  \
# 2           Aamir Khan             Dangal  2016  Biography
# 4   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 8        Ranbir Kapoor             Animal  2023      Drama
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 9       Shah Rukh Khan              Jawan  2023     Action
# 12       Vicky Kaushal             Chaava  2025    Period
# 3         Rajkumar Rao              Stree  2018     Horror
# 11      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 10       Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 5        Ranveer Singh          Padmaavat  2018      Drama
# 7       Hrithik Roshan                War  2019     Action
# 0         Varun Dhawan            Dilwale  2015    Romance
# 6         Akshay Kumar                2.O  2018     Sci-Fi
#
#     BoxOffice in INR CRORE  IMDb  Rank
# 2                     2024   8.4     1
# 4                      456   8.2     2
# 8                      915   8.2     2
# 1                      923   8.0     3
# 9                     1160   7.8     4
# 12                     706   7.8     4
# 3                      180   7.6     5
# 11                     619   7.5     6
# 10                     397   7.2     7
# 5                      585   7.1     8
# 7                      471   6.9     9
# 0                      375   6.2    10
# 6                      745   6.0    11

# %% [markdown]
# # Renaming Columns & Index

# %%
df2.rename(columns={"BoxOffice in INR CRORE": "Collection in Crore"},inplace=True)

# %%
df2
# Out:
#                  Actor               Film  Year      Genre  \
# 0         Varun Dhawan            Dilwale  2015    Romance
# 1          Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 2           Aamir Khan             Dangal  2016  Biography
# 3         Rajkumar Rao              Stree  2018     Horror
# 4   Ayushmann Khurrana          Andhadhun  2018     Comedy
# 5        Ranveer Singh          Padmaavat  2018      Drama
# 6         Akshay Kumar                2.O  2018     Sci-Fi
# 7       Hrithik Roshan                War  2019     Action
# 8        Ranbir Kapoor             Animal  2023      Drama
# 9       Shah Rukh Khan              Jawan  2023     Action
# 10       Karthik Aryan  Bhool Bhulaiyaa 3  2024     Comedy
# 11      Amitabh Bachan      Kalki 2898 AD  2024     Sci-Fi
# 12       Vicky Kaushal             Chaava  2025    Period
#
#     Collection in Crore  IMDb  Rank
# 0                   375   6.2    10
# 1                   923   8.0     3
# 2                  2024   8.4     1
# 3                   180   7.6     5
# 4                   456   8.2     2
# 5                   585   7.1     8
# 6                   745   6.0    11
# 7                   471   6.9     9
# 8                   915   8.2     2
# 9                  1160   7.8     4
# 10                  397   7.2     7
# 11                  619   7.5     6
# 12                  706   7.8     4

# %% [raw]
# To rename all columns:
#
# df.columns = ["Name", "Age", "City"]

# %%
df2=df2[["Rank","Actor","Year","Film","Collection in Crore","Genre","IMDb"]]  # Reorder as desired

# %%
df2
# Out:
#     Rank               Actor  Year               Film  Collection in Crore  \
# 0     10        Varun Dhawan  2015            Dilwale                  375
# 1      3         Salman Khan  2015  Bajrangi Bhaijaan                  923
# 2      1          Aamir Khan  2016             Dangal                 2024
# 3      5        Rajkumar Rao  2018              Stree                  180
# 4      2  Ayushmann Khurrana  2018          Andhadhun                  456
# 5      8       Ranveer Singh  2018          Padmaavat                  585
# 6     11        Akshay Kumar  2018                2.O                  745
# 7      9      Hrithik Roshan  2019                War                  471
# 8      2       Ranbir Kapoor  2023             Animal                  915
# 9      4      Shah Rukh Khan  2023              Jawan                 1160
# 10     7       Karthik Aryan  2024  Bhool Bhulaiyaa 3                  397
# 11     6      Amitabh Bachan  2024      Kalki 2898 AD                  619
# 12     4       Vicky Kaushal  2025             Chaava                  706
#
#         Genre  IMDb
# 0     Romance   6.2
# 1       Drama   8.0
# 2   Biography   8.4
# 3      Horror   7.6
# 4      Comedy   8.2
# 5       Drama   7.1
# 6      Sci-Fi   6.0
# 7      Action   6.9
# 8       Drama   8.2
# 9      Action   7.8
# 10     Comedy   7.2
# 11     Sci-Fi   7.5
# 12    Period    7.8

# %%
df2.sort_values("Rank",inplace=True)

# %%
df2
# Out:
#     Rank               Actor  Year               Film  Collection in Crore  \
# 2      1          Aamir Khan  2016             Dangal                 2024
# 4      2  Ayushmann Khurrana  2018          Andhadhun                  456
# 8      2       Ranbir Kapoor  2023             Animal                  915
# 1      3         Salman Khan  2015  Bajrangi Bhaijaan                  923
# 9      4      Shah Rukh Khan  2023              Jawan                 1160
# 12     4       Vicky Kaushal  2025             Chaava                  706
# 3      5        Rajkumar Rao  2018              Stree                  180
# 11     6      Amitabh Bachan  2024      Kalki 2898 AD                  619
# 10     7       Karthik Aryan  2024  Bhool Bhulaiyaa 3                  397
# 5      8       Ranveer Singh  2018          Padmaavat                  585
# 7      9      Hrithik Roshan  2019                War                  471
# 0     10        Varun Dhawan  2015            Dilwale                  375
# 6     11        Akshay Kumar  2018                2.O                  745
#
#         Genre  IMDb
# 2   Biography   8.4
# 4      Comedy   8.2
# 8       Drama   8.2
# 1       Drama   8.0
# 9      Action   7.8
# 12    Period    7.8
# 3      Horror   7.6
# 11     Sci-Fi   7.5
# 10     Comedy   7.2
# 5       Drama   7.1
# 7      Action   6.9
# 0     Romance   6.2
# 6      Sci-Fi   6.0
