# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # LINEPLOTS

# %%
sns.set_theme(style="dark")
sns.lineplot(x="total_bill" , y="tip" , data=tips)
plt.title("VARIATION OF TIPS WITH TOTAL BILL STUDY")
plt.tight_layout()
plt.grid(True)

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x="total_bill" , y="tip" , data=tips , hue="time") #hue = color code different groups in your data automatically.
plt.title("VARIATION OF TIPS WITH TOTAL BILL STUDY")
plt.tight_layout()
plt.grid(True)

# %% [markdown]
# # BARPLOT

# %%
sns.barplot(x="day", y="total_bill", data=tips , hue="sex",ci=None) # ci removes that black error line
plt.title('Average Bill per Day')
plt.tight_layout()
# Out:
# C:\Users\Siddartha\AppData\Local\Temp\ipykernel_22236\2295827029.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=tips , hue="sex",ci=None) # ci removes that black error line

# %% [markdown]
# # BOXPLOT

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title('Boxplot of Total Bill per Day')  # those dots show data way out 25-75th percentile
plt.tight_layout()

# %% [markdown]
# # HEATMAP

# %%
flights = sns.load_dataset('flights')
pivot_table = flights.pivot(index="month",columns= "year",values= "passengers")

sns.heatmap(pivot_table, annot=True, fmt="d", cmap="YlGnBu")
#annot=True → writes the actual numbers inside the boxes.
#fmt="d" → formats them as integers (no decimals).
#cmap="YlGnBu" → the aesthetic blue-green-yellow gradient.
plt.title('Heatmap of Passengers')
plt.tight_layout()
